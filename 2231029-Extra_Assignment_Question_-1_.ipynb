# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
institute_name = input("Enter your institute name? : ")
print("Your institute name is:", institute_name)
# Out:
# Enter your institute name? :  Hope AI
# Your institute name is: Hope AI

# %%
name = input("Enter your name: ")
print(name)
age = int(input("Enter your age: "))
print(age)
school = input("Enter your school name: ")
print(school)
degree = input("Enter your degree: ")
print(degree)
# Out:
# Enter your name:  Raj
# Raj
# Enter your age:  15
# 15
# Enter your school name:  Guru school
# Guru school
# Enter your degree:  B.E CSE
# B.E CSE

# %%
a=43
b=34
add=a+b
print("a=", a)
print("b=", b)
print("add =",add)
# Out:
# a= 43
# b= 34
# add = 77

# %%
a=43
b=34
Sub=a-b
print("a=", a)
print("b=", b)
print("Sub =",Sub)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
a=63
b=97
Mul=a*b
print("a=", a)
print("b=", b)
print("Mul =",Mul)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
a=76
b=31
Float_Div=a/b
print("a=", a)
print("b=", b)
print("Float Div =",Float_Div)
# Out:
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a=76
b=31
Floor_Div=a//b
print("a=", a)
print("b=", b)
print("Floor Div =",Floor_Div)
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %%
a=76
b=31
Modulo=a%b
print("a=", a)
print("b=", b)
print("Modulo =",Modulo)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
a=4
b=4
Power=a**b
print("a=", a)
print("b=", b)
print("Power =",Power)
# Out:
# a= 4
# b= 4
# Power = 256
